# %% [markdown]
# ## Gamma ray bursts
#
# Let's look at the latest database of Gamma Ray Bursts.
#
#  - The database can be downloaded at https://user-web.icecube.wisc.edu/~grbweb_public/Summary_table.txt
#  - You can find the physical meaning of each variable at https://user-web.icecube.wisc.edu/~grbweb_public/Variables.html
#
#
# This edition of "get your hands dirty" is very open ended (we're getting closer and closer to real research...). You have a cool dataset, explore it! Play with the data, apply some of the tecniques we have seen in classes so far, etc. **Be creative! You're discovering**
#
#
# Some relevant physical questions you might want to tackle include:
#
# - Does the distribution contain different sub-populations? How many?
# - What's the threshold between the classes?
# - If you try two clustering methods, do you get more or less the same?
# - How do methods respond to outliers?
# - What variable(s) shows the multi-modality more evidently?
# - Are all GRBs equally likely to be observed?

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import colors as clr
from scipy.stats import norm
from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, MeanShift, estimate_bandwidth
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.mixture import GaussianMixture
import emcee
import requests
import re
import corner

plt.rcParams["figure.figsize"] = (7, 7)

# %%
#Define functions for clustering

def ComputeKDE(data, x_grid):
    cv = GridSearchCV(KernelDensity(kernel="gaussian"), {"bandwidth": np.arange(0.1, 0.5, 0.05)})
    cv.fit(data)
    b = cv.best_params_["bandwidth"]
    print("Best KDE bandwidth = " + str(b))
    
    kd = KernelDensity(kernel="gaussian", bandwidth=b)
    kd.fit(data)
    kde_pdf = np.exp(kd.score_samples(np.log10(x_grid[:, np.newaxis])))

    return kde_pdf


def ComputeKMeans(data, n_c):
    km = KMeans(n_init="auto", n_clusters=n_c)
    km.fit(data)
    centers = 10**km.cluster_centers_.flatten()
    labels = km.labels_

    if centers[0] > centers[1]:
        centers = centers[::-1]
        labels = np.array(~np.array(labels, dtype=bool), dtype=int)
        
    edge = 10**max(data[labels == 0])  
    
    return centers, edge


def ComputeMeanShift(data, bandwidth, estimate_bw=False):
    if estimate_bw:
        best_bw = estimate_bandwidth(data, quantile=0.2, n_jobs=-1)
        print("Estimated MS bandwidth = " + str(best_bw))

    else:
        best_bw = bandwidth
    
    ms = MeanShift(bandwidth=best_bw, bin_seeding=True, cluster_all=True, n_jobs=-1)
    ms.fit(data)
    centers = 10**ms.cluster_centers_.flatten()
    labels = ms.labels_

    #Order the labels based on the cluster centers positions

    for i in range(0, len(centers)):

        #For every pair of labels, switch them if the center of the smaller label is bigger than the center of the other label
        for j in range(i + 1, len(centers)):
            if centers[i] > centers[j]:
                temp1 = centers[i].copy()
                temp2 = centers[j].copy()

                i_idx = np.where(labels == np.where(centers == centers[i])[0])[0]
                j_idx = np.where(labels == np.where(centers == centers[j])[0])[0]

                centers[i] = temp2
                centers[j] = temp1
                
                labels[i_idx] = np.unique(np.where(centers == centers[j])[0])
                labels[j_idx] = np.unique(np.where(centers == centers[i])[0])

    #Order the edges
    
    edges = []

    for i in range(0, len(np.unique(np.argsort(centers))) - 1):    #1D problem: every edge is located where the bigger element with a given label ends 
        edges.append(10**max(data[labels == i]))  

    print("Number of MS clusters = " + str(len(centers)))

    return centers, edges


def ComputeGMM(data, x_grid, n_g=2, do_CV=False):
    if do_CV:
        cv = GridSearchCV(GaussianMixture(), {"n_components": np.arange(1, 5)}, cv=10)
        cv.fit(data)
        n_best = cv.best_params_["n_components"]
        print("Best number of gaussians = " + str(n_best))

    else:
        n_best = n_g
    
    gmm = GaussianMixture(n_components=n_best)
    gmm.fit(data)

    gmm_pdf = np.exp(gmm.score_samples(np.log10(x_grid[:, np.newaxis])))
    resp = gmm.predict_proba(data)
    means = 10**gmm.means_

    return gmm_pdf, resp, means

# %%
req = requests.get('https://user-web.icecube.wisc.edu/~grbweb_public/Summary_table.txt')

with open("Summary_table.txt", "wb") as f:
    f.write(req.content)

# %%
dataset = np.loadtxt("Summary_table.txt", dtype="str", unpack=True)

with open("Summary_table.txt", "r") as f:
    names = np.array([line.replace(" ", "_") for line in re.split(r"\s{2,}", f.readlines()[1].replace("#", "").strip())])

print(names)

data = dict(zip(names, dataset))
# Out:
# ['GRB_name' 'GRB_name_Fermi' 'T0' 'ra' 'decl' 'pos_error' 'T90'
#  'T90_error' 'T90_start' 'fluence' 'fluence_error' 'redshift' "'T100'"
#  'GBM_located' 'mjd_(T0)']

# %%
#Get data (including missing data)

T90 = np.array(data["T90"], dtype=float)
T90_err = np.array(data["T90_error"], dtype=float)
fluence = np.array(data["fluence"], dtype=float)
f_err = np.array(data["fluence_error"], dtype=float)
z = np.array(data["redshift"], dtype=float)

# %%
#Remove missing values

missing_T90 = ~np.isnan(np.log(T90))
missing_f = np.logical_and(~np.isnan(np.log(fluence)), fluence != 0.)
missing_z = ~np.isnan(np.log(z))

T90 = T90[missing_T90]
T90_err = T90_err[missing_T90]
fluence = fluence[missing_f]
f_err = f_err[missing_f]
z = z[missing_z]
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_14220\2353401470.py:3: RuntimeWarning: invalid value encountered in log
#   missing_T90 = ~np.isnan(np.log(T90))
# C:\Users\Utente\AppData\Local\Temp\ipykernel_14220\2353401470.py:4: RuntimeWarning: divide by zero encountered in log
#   missing_f = np.logical_and(~np.isnan(np.log(fluence)), fluence != 0.)
# C:\Users\Utente\AppData\Local\Temp\ipykernel_14220\2353401470.py:4: RuntimeWarning: invalid value encountered in log
#   missing_f = np.logical_and(~np.isnan(np.log(fluence)), fluence != 0.)
# C:\Users\Utente\AppData\Local\Temp\ipykernel_14220\2353401470.py:5: RuntimeWarning: invalid value encountered in log
#   missing_z = ~np.isnan(np.log(z))

# %%
#Remove values that are missing in at least one of the arrays, so that they have the same number of entries and can be inserted in a single array

missing_all = np.logical_and(np.logical_and(missing_T90, missing_f), missing_z)
data_all = np.array([data["T90"], data["fluence"], data["redshift"]], dtype=float).T[missing_all]
log_data_all = np.log10(data_all)

# %%
#Cornerplot of T90, fluence and redshift

corner_all = corner.corner(data_all, labels=["$T_{90}$", "Fluence", "z"], quantiles=[0.50], axes_scale=["log", "log", "log"], color="darkcyan")

# %% [markdown]
# ## T90

# %%
#Plot histogram
    
plt.figure()
plt.hist(T90, color="darkcyan", bins=np.logspace(-2, 3, 100))
plt.xscale("log")

# %% [markdown]
# There appear to be two peaks in the $T_{90}$ distribution.

# %%
T90_ml = np.log10(T90)[:, np.newaxis]
x_grid_t90 = np.logspace(-2, 3, 1000)

#KDE
kde_pdf_t90 = ComputeKDE(T90_ml, x_grid_t90)

#KMeans

km_centers_t90, km_edge_t90 = ComputeKMeans(T90_ml, 2)

#MeanShift

ms_centers_t90, ms_edges_t90 = ComputeMeanShift(T90_ml, 0.3, estimate_bw=True)    #Estimate bandwidth such that the algorithm finds two clusters

#GMM

gmm_pdf_t90, gmm_resp_t90, gmm_means_t90 = ComputeGMM(T90_ml, x_grid_t90, do_CV=True)
# Out:
# Best KDE bandwidth = 0.1
# Estimated MS bandwidth = 0.3679307334602545
# Number of MS clusters = 2
# Best number of gaussians = 2

# %%
#Plot the clustering results

fig, ax = plt.subplots()

#KDE
plt.plot(x_grid_t90, kde_pdf_t90, label="KDE")

#KMeans
ax.axvline(km_centers_t90[0], color="red", label="KM centers")
ax.axvline(km_centers_t90[1], color="red")
ax.axvline(km_edge_t90, color="red", linestyle="--", label="KM edge = " + str(km_edge_t90))

#Meanshift
ax.axvline(ms_centers_t90[0], color="black", label="MS centers")

for i in ms_centers_t90[1:]:
    ax.axvline(i, color="black")

for i in ms_edges_t90:
    ax.axvline(i, color="black", linestyle="--", label="MS edge = " + str(i))

#GMM
plt.plot(x_grid_t90, gmm_pdf_t90, color="green", label="GMM")
ax.axvline(gmm_means_t90[0], color="lime", label="GMM means")
ax.axvline(gmm_means_t90[1], color="lime")

plt.xlabel("$T_{90}$")
plt.xscale("log")
plt.legend()

print("KM centers = " + str(km_centers_t90))
print("MS centers = " + str(ms_centers_t90))
print("GMM centers = " + str(gmm_means_t90))
# Out:
# KM centers = [ 0.91138579 33.22317088]
# MS centers = [ 1.00276184 32.03521486]
# GMM centers = [[30.63067431]
#  [ 0.95434963]]

# %% [markdown]
# The three clustering algorithms all give similar results when using the $T_{90}$ data. So the $T_{90}$ distribution appears to have a bimodality, separating GRBs in "short GRBs" and "long GRBs".

# %% [markdown]
# ## Fluence

# %%
#Plot histogram
    
plt.figure()
plt.hist(fluence, color="darkcyan", bins=np.logspace(-10, -2, 100))
plt.xlabel("Fluence")
plt.xscale("log")

# %% [markdown]
# The bimodality can't really be seen by looking at the fluence data.

# %% [markdown]
# ## Redshift

# %%
#Plot histogram
    
plt.figure()
plt.hist(z, color="darkcyan", bins=np.logspace(-2, 2, 100))
plt.xlabel("$z$")
plt.xscale("log")

# %% [markdown]
# I try to find the same bimodality observed in the $T_{90}$ by looking at the redshift data.

# %%
z_ml = np.log10(z)[:, np.newaxis]
x_grid_z = np.logspace(-2, 2, 1000)

#KDE
kde_pdf_z = ComputeKDE(z_ml, x_grid_z)

#KMeans

km_centers, km_edge = ComputeKMeans(z_ml, 2)

#MeanShift

ms_centers, ms_edges = ComputeMeanShift(z_ml, 0.4)    #Bandwidth such that the algorithm finds two clusters

#GMM

gmm_pdf, gmm_resp, gmm_means = ComputeGMM(z_ml, x_grid_z, n_g=2)
# Out:
# Best KDE bandwidth = 0.1
# Number of MS clusters = 2

# %%
#Plot the clustering results

fig, ax = plt.subplots()

#KDE
plt.plot(x_grid_z, kde_pdf_z, label="KDE")

#KMeans
ax.axvline(km_centers[0], color="red", label="KM centers")
ax.axvline(km_centers[1], color="red")
ax.axvline(km_edge, color="red", linestyle="--", label="KM edge = " + str(km_edge))

#Meanshift
ax.axvline(ms_centers[0], color="black", label="MS centers")

for i in ms_centers[1:]:
    ax.axvline(i, color="black")

for i in ms_edges:
    ax.axvline(i, color="black", linestyle="--", label="MS edge = " + str(ms_edges[0]))

#GMM
plt.plot(x_grid_z, gmm_pdf, color="green", label="GMM")
ax.axvline(gmm_means[0], color="lime", label="GMM means")
ax.axvline(gmm_means[1], color="lime")

plt.xlabel("$z$")
plt.xscale("log")
plt.legend()

print("KM centers = " + str(km_centers))
print("MS centers = " + str(ms_centers))
print("GMM centers = " + str(gmm_means))
# Out:
# KM centers = [0.35069403 2.12739887]
# MS centers = [0.01011714 1.78889384]
# GMM centers = [[0.45934445]
#  [1.84913937]]

# %% [markdown]
# The presence of two modes in the redshift distribution is way less evident than in $T_{90}$, so the clustering algorithms can only find one of the peaks.

# %% [markdown]
# ## GMM with measurement errors

# %% [markdown]
# Since the $T_{90}$ measurements have uncertainties i try to fit a GMM considering the heteroscedastic errors.

# %%
#Plot of T90 and T90 errors
plt.scatter(T90, T90_err, color="darkcyan", alpha=0.2)
plt.xlabel("$T_{90}$")
plt.ylabel("$T_{90}$ uncertainties")
plt.xscale("log")
plt.yscale("log")

# %% [markdown]
# I assume that the errors are normally distributed, so the total $\log{T_{90}}$ PDF is the convolution between the GMM and the error gaussian.

# %%
#GMM model with measurement uncertainties (convolution between GMM and error gaussian)
def GMMErrors(params, x, x_err):
    a, mu_1, mu_2, sigma_1, sigma_2 = params
    
    e_1 = np.sqrt(sigma_1**2 + x_err**2)
    e_2 = np.sqrt(sigma_2**2 + x_err**2)
    
    return a * norm(mu_1, e_1).pdf(x) + (1 - a) * norm(mu_2, e_2).pdf(x)


def logLikelihood(params, x, x_err):
    return np.sum(np.log(GMMErrors(params, x, x_err)))


def logPrior(params):
    a, mu_1, mu_2, sigma_1, sigma_2 = params

    if (0 < a < 1) and (1e-2 < mu_1 < 1e3) and (1e-2 < mu_2 < 1e3) and (0 < sigma_1 < 200) and (0 < sigma_2 < 200):
        return -np.log(sigma_1) - np.log(sigma_2)
    
    else:
        return -np.inf


def logPosterior(params, x, x_err):
    prior = logPrior(params)

    if prior == -np.inf:
        return -np.inf

    else:
        return prior + logLikelihood(params, x, x_err)

# %% [markdown]
# This problem has five parameters and a bimodality: the standard stretch move implemented by emcee doesn't give an accurate estimation of the autocorrelation length (such that $\tau < N_{steps}/50$). As suggested in the emcee documentation, for this type of problem I use a combination of two differential evolution algorithms.

# %%
#Use MCMC

n_walkers = 20
n_dim = 5
n_steps = 20000

#Save the chain on a file, since it takes a while to run it every time

backend = emcee.backends.HDFBackend("GMM_errors.h5")
# backend.reset(n_walkers, n_dim)

start_point = np.random.random((n_walkers, n_dim)) + [0.5, 0.9, 1, 0, 2]

sampler = emcee.EnsembleSampler(n_walkers, n_dim, logPosterior, args=[np.log10(T90), T90_err / (T90 * np.log(10))], 
                                moves=[(emcee.moves.DEMove(), 0.7), (emcee.moves.DESnookerMove(), 0.3)],
                                backend=backend, 
                                threads=-1)
sampler.run_mcmc(start_point, n_steps, progress=True)

acc_fraction = sampler.acceptance_fraction
print("Acceptance fraction for each walker = " + str(acc_fraction))
# Out:
#   0%|                                                                                        | 0/20000 [00:00<?, ?it/s]D:\anaconda3\envs\astroML\lib\site-packages\emcee\moves\red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|████████████████████████████████████████████████████████████████████████████| 20000/20000 [18:48<00:00, 17.72it/s]
# Acceptance fraction for each walker = [0.463   0.46095 0.455   0.45525 0.45465 0.4606  0.4571  0.4607  0.45665
#  0.4693  0.4577  0.4582  0.46335 0.459   0.46065 0.46235 0.45965 0.45915
#  0.4605  0.4594 ]

# %%
reader = emcee.backends.HDFBackend("GMM_errors.h5")

#Burn in and thinning

burn = 2000
thin = int(max(reader.get_autocorr_time()))
trace = reader.get_chain(discard=burn, thin=thin, flat=True)

#Traceplot

x_grid = np.arange(0, trace.shape[0])

fig, ax = plt.subplots(3, 2, figsize=(8, 10))
par_names = ["$a$", "$\\mu_1$", "$\\mu_2$", "$\sigma_1$", "$\sigma_2$"]
par_count = 0

for i in range(0, 3):
    for j in range(0, 2):
        if i != 2 or (i == 2 and j == 0):
            ax[i, j].plot(x_grid, trace[:, par_count])
            ax[i, j].set_xlabel(par_names[par_count])
            par_count += 1

# %%
fig_corner = corner.corner(trace, labels=["a", "$\\mu_1$", "$\\mu_2$", "$\sigma_1$", "$\sigma_2$"], show_titles=True, levels=[0.39, 0.68, 0.90], quantiles=[0.05, 0.50, 0.95], color="darkcyan")

# %%
#Plot the gaussian model with errors

medians = np.median(trace, axis=0)
credible_95 = np.quantile(trace, 0.95, axis=0) - medians
credible_005 = medians - np.quantile(trace, 0.05, axis=0)
grid = np.linspace(0.01, 1000, 1000)

fig_gmm, ax_gmm = plt.subplots()
plt.hist(np.log10(T90), np.linspace(-2, 3, 100), color="darkcyan", alpha=0.7, density=True)
plt.plot(np.sort(np.log10(T90)), GMMErrors(medians, np.sort(np.log10(T90)), 0), color="crimson", label="GMM with measurement uncertainties")
ax_gmm.axvline(medians[1], color="black", linestyle="--", label="Gaussian 1: $\\mu_1 = " + f"{medians[1]:.2f}" + 
    "^{+" + f"{credible_95[1]:.2f}" + "}_{-" + f"{credible_005[1]:.2f}" + "}$")
ax_gmm.axvline(medians[2], color="red", linestyle="--", label="Gaussian 2: $\\mu_2 = " + f"{medians[2]:.2f}" + 
    "^{+" + f"{credible_95[2]:.2f}" + "}_{-" + f"{credible_005[2]:.2f}" + "}$")
plt.xlabel("$\log{T_{90}}$")
plt.legend()

#Print gaussian coefficients

print("Mixing coefficients:")

if medians[1] > medians[2]:
    print("Gaussian 1 (long GRBs): " + str(medians[0]))
    print("Gaussian 2 (short GRBs): " + str(1 - medians[0]))

else:
    print("Gaussian 1 (short GRBs): " + str(medians[0]))
    print("Gaussian 2 (long GRBs): " + str(1 - medians[0]))
# Out:
# Mixing coefficients:
# Gaussian 1 (long GRBs): 0.7648168523441506
# Gaussian 2 (short GRBs): 0.23518314765584936

# %% [markdown]
# ## Clustering with $T_{90}$, fluence and redshift

# %% [markdown]
# Now I try clustering with all three features with and without using PCA.

# %%
#Scale the data first

scaler = StandardScaler()
scaler.fit(log_data_all)
data_s = scaler.transform(log_data_all)

# %%
#Use KMeans clustering

km = KMeans(n_init="auto", n_clusters=2)
km.fit(data_s)

labels = km.predict(data_s)
km_centers = km.cluster_centers_

# %%
#If the first cluster is at higher times than the first then it repersents LGRBs (label == 0), otherwise it's the opposite

if np.mean(T90_miss_all[labels == 0]) < np.mean(T90_miss_all[labels == 1]):
    labels = np.array(~np.array(labels, dtype=bool), dtype=int)    #Switch the labels

# %% [markdown]
# ## PCA

# %% [markdown]
# I also tried using PCA to make clustering easier, using $T_{90}$, fluence and redshift.

# %%
pca = PCA(n_components=2)
pca.fit(data_s)
data_red = pca.transform(data_s)

# %%
plt.figure()
plt.scatter(data_red[:, 0], data_red[:, 1], color="darkcyan", alpha=0.5)
plt.xlabel("Component 0")
plt.ylabel("Component 1")
# Out:
# Text(0, 0.5, 'Component 1')

# %%
#Use KMeans clustering

km_pca = KMeans(n_init="auto", n_clusters=2)
km_pca.fit(data_red)

labels_pca = km_pca.predict(data_red)
km_centers_pca = km_pca.cluster_centers_

# %%
T90_miss_all = data_all[:, 0]

#If the first cluster is at higher times than the first then it repersents LGRBs (label == 0), otherwise it's the opposite

if np.mean(T90_miss_all[labels_pca == 0]) < np.mean(T90_miss_all[labels_pca == 1]):
    labels_pca = np.array(~np.array(labels_pca, dtype=bool), dtype=int)    #Switch the labels

# %%
#PCA components plot with clustering

plt.figure()
plt.scatter(data_red[:, 0][labels_pca == 0], data_red[:, 1][labels_pca == 0], color="darkcyan", alpha=0.4, label="Long GRBs")
plt.scatter(data_red[:, 0][labels_pca == 1], data_red[:, 1][labels_pca == 1], color="crimson", alpha=0.4, label="Short GRBs")
plt.scatter(km_centers_pca[:, 0], km_centers_pca[:, 1], color="black", label="Cluster centers")
plt.xlabel("Component 0")
plt.ylabel("Component 1")
plt.legend()

# %% [markdown]
# Now I compare clustering with and without PCA.

# %%
print("Accuracy of clustering with PCA, with respect to without PCA = " + str(accuracy_score(labels, labels_pca)))
print("Confusion matrix (labels on the i-th row predicted without PCA, and on the j-th column with PCA):")
print(confusion_matrix(labels, labels_pca))
# Out:
# Accuracy of clustering with PCA, with respect to without PCA = 0.976068376068376
# Confusion matrix (labels on the i-th row predicted without PCA, and on the j-th column with PCA):
# [[456  14]
#  [  0 115]]

# %% [markdown]
# PCA predicts more short GRBs (label == 1), but overall it gives similar results to clustering without it.

# %%
#Plot the T90 distribution with the clusters found by KMeans and the gaussians found by also considering the T90 errors

fig_pca = plt.figure()
ax_pca = fig_pca.add_subplot()
plt.hist(T90_miss_all[labels_pca == 0], bins=np.logspace(-2, 3, 100), color="darkcyan", alpha=0.5, label="Long GRBs")
plt.hist(T90_miss_all[labels_pca == 1], bins=np.logspace(-2, 3, 100), color="crimson", alpha=0.5, label="Short GRBs")
ax_pca.axvline(10**medians[1], color="black", linestyle="--", label="Gaussian 1: $\\mu_1 = " + f"{10**medians[1]:.2f}" + 
    "^{+" + f"{credible_95[1]:.2f}" + "}_{-" + f"{credible_005[1]:.2f}" + "}$")
ax_pca.axvline(10**medians[2], color="crimson", linestyle="--", label="Gaussian 2: $\\mu_2 = " + f"{10**medians[2]:.2f}" + 
    "^{+" + f"{credible_95[2]:.2f}" + "}_{-" + f"{credible_005[2]:.2f}" + "}$")
plt.title("PCA clustering of $T_{90}$ and GMM fit with errors")
plt.xlabel("$T_{90}$")
plt.xscale("log")
plt.legend()

# %%
fluence_miss_all = data_all[:, 1]

plt.figure()
plt.hist(fluence_miss_all[labels_pca == 0], bins=np.logspace(-10, -2, 100), color="darkcyan", alpha=0.5, label="Long GRBs")
plt.hist(fluence_miss_all[labels_pca == 1], bins=np.logspace(-10, -2, 100), color="crimson", alpha=0.5, label="Short GRBs")
plt.title("PCA clustering of fluence")
plt.xlabel("Fluence")
plt.xscale("log")
plt.legend()

# %%
z_miss_all = data_all[:, 2]

plt.figure()
plt.hist(z_miss_all[labels_pca == 0], bins=np.logspace(-2, 2, 100), color="darkcyan", alpha=0.5, label="Long GRBs")
plt.hist(z_miss_all[labels_pca == 1], bins=np.logspace(-2, 2, 100), color="crimson", alpha=0.5, label="Short GRBs")
plt.title("PCA clustering of redshift")
plt.xlabel("z")
plt.xscale("log")
plt.legend()

# %% [markdown]
# Long GRBs seem to be located at higher redshift than short GRBs.
